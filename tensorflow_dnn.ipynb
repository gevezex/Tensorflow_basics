# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# %% [markdown]
# ## 1. Data stuff

# %%
from sklearn.datasets import load_iris
data = load_iris()

# %%
data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
X_data = data.data
y_data = data.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((112, 4), (38, 4))

# %% [markdown]
# #### Next Batch function

# %%
def next_batch(num, data, labels):
    '''
    Return a total of `num` random samples and labels. 
    '''
    idx = np.arange(0 , len(data.data))
    np.random.shuffle(idx)
    idx = idx[:num]
    data_shuffle = [data[ i] for i in idx]
    labels_shuffle = [labels[ i] for i in idx]

    return np.asarray(data_shuffle), np.asarray(labels_shuffle)

# %% [markdown]
# ## 2. Placeholders for input and output data

# %%
# Lets reset the graph first for undesired outputs
reset_graph()

# %%
n_features = 4

X = tf.placeholder(tf.float32, shape=(None, n_features), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

# %% [markdown]
# ## 3. Define the deep network

# %%
n_hidden1 = 400
n_hidden2 = 200
n_outputs = 3

with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1", activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2", activation=tf.nn.relu)
    logits  = tf.layers.dense(hidden2, n_outputs, name="outputs")

# %% [markdown]
# ## 4. What is the loss function

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %% [markdown]
# ## 5. What is the optimizer

# %%
learning_rate = 0.001

with tf.name_scope("Training"):
    #optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
    optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate, momentum=0.9, use_nesterov=True)
    training_op = optimizer.minimize(loss)

# %% [markdown]
# #### Calculate accuracy

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %% [markdown]
# ## 6. Execution Phase

# %%
n_epochs=500
batch_size=50

init = tf.global_variables_initializer()
saver = tf.train.Saver()

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(int(np.ceil(len(X_train)/batch_size))):
            X_batch, y_batch = next_batch(batch_size, X_train, y_train)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        print(epoch, "Train accuracy:", acc_train)
    save_path = saver.save(sess, "./my_model_final,ckpt")
# Out:
# 0 Train accuracy: 0.62
# 1 Train accuracy: 0.54
# 2 Train accuracy: 0.64
# 3 Train accuracy: 0.64
# 4 Train accuracy: 0.7
# 5 Train accuracy: 0.62
# 6 Train accuracy: 0.66
# 7 Train accuracy: 0.66
# 8 Train accuracy: 0.54
# 9 Train accuracy: 0.7
# 10 Train accuracy: 0.68
# 11 Train accuracy: 0.7
# 12 Train accuracy: 0.62
# 13 Train accuracy: 0.94
# 14 Train accuracy: 0.82
# 15 Train accuracy: 0.94
# 16 Train accuracy: 0.9
# 17 Train accuracy: 0.86
# 18 Train accuracy: 0.9
# 19 Train accuracy: 0.84
# 20 Train accuracy: 0.92
# 21 Train accuracy: 0.66
# 22 Train accuracy: 0.76
# 23 Train accuracy: 0.94
# 24 Train accuracy: 0.86
# 25 Train accuracy: 0.88
# 26 Train accuracy: 0.94
# 27 Train accuracy: 0.98
# 28 Train accuracy: 0.96
# 29 Train accuracy: 0.96
# 30 Train accuracy: 0.92
# 31 Train accuracy: 0.88
# 32 Train accuracy: 0.98
# 33 Train accuracy: 1.0
# 34 Train accuracy: 0.98
# 35 Train accuracy: 0.98
# 36 Train accuracy: 0.98
# 37 Train accuracy: 0.94
# 38 Train accuracy: 0.88
# 39 Train accuracy: 0.88
# 40 Train accuracy: 0.92
# 41 Train accuracy: 0.9
# 42 Train accuracy: 0.96
# 43 Train accuracy: 0.94
# 44 Train accuracy: 0.92
# 45 Train accuracy: 0.94
# 46 Train accuracy: 0.96
# 47 Train accuracy: 0.94
# 48 Train accuracy: 0.94
# 49 Train accuracy: 0.94
# 50 Train accuracy: 0.92
# 51 Train accuracy: 0.94
# 52 Train accuracy: 0.94
# 53 Train accuracy: 1.0
# 54 Train accuracy: 0.94
# 55 Train accuracy: 0.98
# 56 Train accuracy: 0.96
# 57 Train accuracy: 0.92
# 58 Train accuracy: 0.9
# 59 Train accuracy: 0.92
# 60 Train accuracy: 1.0
# 61 Train accuracy: 0.96
# 62 Train accuracy: 0.96
# 63 Train accuracy: 1.0
# 64 Train accuracy: 0.96
# 65 Train accuracy: 0.98
# 66 Train accuracy: 0.98
# 67 Train accuracy: 0.96
# 68 Train accuracy: 1.0
# 69 Train accuracy: 0.96
# 70 Train accuracy: 0.96
# 71 Train accuracy: 0.94
# 72 Train accuracy: 0.96
# 73 Train accuracy: 1.0
# 74 Train accuracy: 0.98
# 75 Train accuracy: 0.98
# 76 Train accuracy: 0.96
# 77 Train accuracy: 0.98
# 78 Train accuracy: 0.98
# 79 Train accuracy: 1.0
# 80 Train accuracy: 0.94
# 81 Train accuracy: 0.98
# 82 Train accuracy: 0.98
# 83 Train accuracy: 0.98
# 84 Train accuracy: 0.98
# 85 Train accuracy: 0.96
# 86 Train accuracy: 0.96
# 87 Train accuracy: 0.94
# 88 Train accuracy: 0.98
# 89 Train accuracy: 0.98
# 90 Train accuracy: 0.98
# 91 Train accuracy: 0.98
# 92 Train accuracy: 0.96
# 93 Train accuracy: 0.98
# 94 Train accuracy: 0.96
# 95 Train accuracy: 0.98
# 96 Train accuracy: 0.96
# 97 Train accuracy: 0.98
# 98 Train accuracy: 0.96
# 99 Train accuracy: 0.98
# 100 Train accuracy: 0.96
# 101 Train accuracy: 1.0
# 102 Train accuracy: 0.96
# 103 Train accuracy: 0.96
# 104 Train accuracy: 0.96
# 105 Train accuracy: 1.0
# 106 Train accuracy: 0.98
# 107 Train accuracy: 0.98
# 108 Train accuracy: 0.96
# 109 Train accuracy: 0.94
# 110 Train accuracy: 0.98
# 111 Train accuracy: 0.98
# 112 Train accuracy: 0.96
# 113 Train accuracy: 0.96
# 114 Train accuracy: 0.96
# 115 Train accuracy: 0.98
# 116 Train accuracy: 0.98
# 117 Train accuracy: 0.94
# 118 Train accuracy: 1.0
# 119 Train accuracy: 0.98
# 120 Train accuracy: 1.0
# 121 Train accuracy: 0.98
# 122 Train accuracy: 1.0
# 123 Train accuracy: 1.0
# 124 Train accuracy: 0.96
# 125 Train accuracy: 0.98
# 126 Train accuracy: 0.96
# 127 Train accuracy: 1.0
# 128 Train accuracy: 0.96
# 129 Train accuracy: 0.98
# 130 Train accuracy: 0.98
# 131 Train accuracy: 0.98
# 132 Train accuracy: 0.98
# 133 Train accuracy: 0.94
# 134 Train accuracy: 0.98
# 135 Train accuracy: 0.98
# 136 Train accuracy: 0.98
# 137 Train accuracy: 0.96
# 138 Train accuracy: 0.98
# 139 Train accuracy: 0.94
# 140 Train accuracy: 0.94
# 141 Train accuracy: 0.96
# 142 Train accuracy: 1.0
# 143 Train accuracy: 0.98
# 144 Train accuracy: 0.98
# 145 Train accuracy: 0.98
# 146 Train accuracy: 0.98
# 147 Train accuracy: 0.96
# 148 Train accuracy: 0.98
# 149 Train accuracy: 0.96
# 150 Train accuracy: 0.98
# 151 Train accuracy: 0.98
# 152 Train accuracy: 0.96
# 153 Train accuracy: 0.94
# 154 Train accuracy: 0.96
# 155 Train accuracy: 0.98
# 156 Train accuracy: 0.98
# 157 Train accuracy: 0.96
# 158 Train accuracy: 1.0
# 159 Train accuracy: 0.96
# 160 Train accuracy: 0.98
# 161 Train accuracy: 0.98
# 162 Train accuracy: 1.0
# 163 Train accuracy: 0.98
# 164 Train accuracy: 0.98
# 165 Train accuracy: 0.96
# 166 Train accuracy: 0.96
# 167 Train accuracy: 0.96
# 168 Train accuracy: 0.98
# 169 Train accuracy: 0.96
# 170 Train accuracy: 0.98
# 171 Train accuracy: 1.0
# 172 Train accuracy: 1.0
# 173 Train accuracy: 0.96
# 174 Train accuracy: 0.94
# 175 Train accuracy: 1.0
# 176 Train accuracy: 0.98
# 177 Train accuracy: 0.98
# 178 Train accuracy: 0.98
# 179 Train accuracy: 0.96
# 180 Train accuracy: 0.98
# 181 Train accuracy: 1.0
# 182 Train accuracy: 0.98
# 183 Train accuracy: 0.98
# 184 Train accuracy: 1.0
# 185 Train accuracy: 0.98
# 186 Train accuracy: 0.94
# 187 Train accuracy: 0.98
# 188 Train accuracy: 0.98
# 189 Train accuracy: 0.98
# 190 Train accuracy: 1.0
# 191 Train accuracy: 0.96
# 192 Train accuracy: 0.98
# 193 Train accuracy: 1.0
# 194 Train accuracy: 1.0
# 195 Train accuracy: 0.98
# 196 Train accuracy: 0.98
# 197 Train accuracy: 0.98
# 198 Train accuracy: 0.96
# 199 Train accuracy: 0.98
# 200 Train accuracy: 0.98
# 201 Train accuracy: 0.98
# 202 Train accuracy: 0.98
# 203 Train accuracy: 0.96
# 204 Train accuracy: 1.0
# 205 Train accuracy: 0.96
# 206 Train accuracy: 0.98
# 207 Train accuracy: 0.96
# 208 Train accuracy: 0.96
# 209 Train accuracy: 1.0
# 210 Train accuracy: 1.0
# 211 Train accuracy: 0.98
# 212 Train accuracy: 0.98
# 213 Train accuracy: 0.94
# 214 Train accuracy: 0.96
# 215 Train accuracy: 0.96
# 216 Train accuracy: 0.98
# 217 Train accuracy: 0.98
# 218 Train accuracy: 1.0
# 219 Train accuracy: 0.98
# 220 Train accuracy: 1.0
# 221 Train accuracy: 0.96
# 222 Train accuracy: 0.98
# 223 Train accuracy: 0.98
# 224 Train accuracy: 0.96
# 225 Train accuracy: 1.0
# 226 Train accuracy: 0.94
# 227 Train accuracy: 0.96
# 228 Train accuracy: 0.98
# 229 Train accuracy: 0.94
# 230 Train accuracy: 0.96
# 231 Train accuracy: 0.98
# 232 Train accuracy: 0.96
# 233 Train accuracy: 0.96
# 234 Train accuracy: 0.96
# 235 Train accuracy: 0.98
# 236 Train accuracy: 0.96
# 237 Train accuracy: 1.0
# 238 Train accuracy: 1.0
# 239 Train accuracy: 1.0
# 240 Train accuracy: 1.0
# 241 Train accuracy: 0.98
# 242 Train accuracy: 0.96
# 243 Train accuracy: 0.98
# 244 Train accuracy: 0.96
# 245 Train accuracy: 1.0
# 246 Train accuracy: 0.96
# 247 Train accuracy: 0.98
# 248 Train accuracy: 1.0
# 249 Train accuracy: 1.0
# 250 Train accuracy: 0.98
# 251 Train accuracy: 1.0
# 252 Train accuracy: 1.0
# 253 Train accuracy: 1.0
# 254 Train accuracy: 0.98
# 255 Train accuracy: 1.0
# 256 Train accuracy: 1.0
# 257 Train accuracy: 0.96
# 258 Train accuracy: 0.98
# 259 Train accuracy: 1.0
# 260 Train accuracy: 0.98
# 261 Train accuracy: 0.96
# 262 Train accuracy: 0.96
# 263 Train accuracy: 0.96
# 264 Train accuracy: 0.98
# 265 Train accuracy: 0.98
# 266 Train accuracy: 0.98
# 267 Train accuracy: 1.0
# 268 Train accuracy: 0.96
# 269 Train accuracy: 1.0
# 270 Train accuracy: 0.98
# 271 Train accuracy: 0.98
# 272 Train accuracy: 0.98
# 273 Train accuracy: 0.98
# 274 Train accuracy: 0.98
# 275 Train accuracy: 1.0
# 276 Train accuracy: 1.0
# 277 Train accuracy: 0.98
# 278 Train accuracy: 0.98
# 279 Train accuracy: 0.98
# 280 Train accuracy: 0.98
# 281 Train accuracy: 0.98
# 282 Train accuracy: 0.98
# 283 Train accuracy: 0.98
# 284 Train accuracy: 0.98
# 285 Train accuracy: 0.98
# 286 Train accuracy: 0.98
# 287 Train accuracy: 0.98
# 288 Train accuracy: 1.0
# 289 Train accuracy: 1.0
# 290 Train accuracy: 0.96
# 291 Train accuracy: 1.0
# 292 Train accuracy: 0.98
# 293 Train accuracy: 0.96
# 294 Train accuracy: 0.98
# 295 Train accuracy: 1.0
# 296 Train accuracy: 0.98
# 297 Train accuracy: 0.98
# 298 Train accuracy: 0.98
# 299 Train accuracy: 0.98
# 300 Train accuracy: 0.98
# 301 Train accuracy: 0.98
# 302 Train accuracy: 0.98
# 303 Train accuracy: 0.98
# 304 Train accuracy: 0.94
# 305 Train accuracy: 0.96
# 306 Train accuracy: 0.98
# 307 Train accuracy: 1.0
# 308 Train accuracy: 0.96
# 309 Train accuracy: 0.98
# 310 Train accuracy: 0.94
# 311 Train accuracy: 0.98
# 312 Train accuracy: 0.98
# 313 Train accuracy: 0.98
# 314 Train accuracy: 0.98
# 315 Train accuracy: 1.0
# 316 Train accuracy: 1.0
# 317 Train accuracy: 0.98
# 318 Train accuracy: 1.0
# 319 Train accuracy: 0.96
# 320 Train accuracy: 1.0
# 321 Train accuracy: 1.0
# 322 Train accuracy: 0.98
# 323 Train accuracy: 1.0
# 324 Train accuracy: 1.0
# 325 Train accuracy: 0.96
# 326 Train accuracy: 0.98
# 327 Train accuracy: 0.98
# 328 Train accuracy: 0.98
# 329 Train accuracy: 0.96
# 330 Train accuracy: 0.96
# 331 Train accuracy: 1.0
# 332 Train accuracy: 0.96
# 333 Train accuracy: 1.0
# 334 Train accuracy: 0.96
# 335 Train accuracy: 1.0
# 336 Train accuracy: 0.98
# 337 Train accuracy: 1.0
# 338 Train accuracy: 0.98
# 339 Train accuracy: 0.98
# 340 Train accuracy: 1.0
# 341 Train accuracy: 0.96
# 342 Train accuracy: 0.98
# 343 Train accuracy: 1.0
# 344 Train accuracy: 0.98
# 345 Train accuracy: 0.96
# 346 Train accuracy: 0.98
# 347 Train accuracy: 0.98
# 348 Train accuracy: 0.98
# 349 Train accuracy: 0.96
# 350 Train accuracy: 0.98
# 351 Train accuracy: 1.0
# 352 Train accuracy: 0.98
# 353 Train accuracy: 0.96
# 354 Train accuracy: 0.98
# 355 Train accuracy: 1.0
# 356 Train accuracy: 1.0
# 357 Train accuracy: 0.98
# 358 Train accuracy: 0.96
# 359 Train accuracy: 0.96
# 360 Train accuracy: 0.98
# 361 Train accuracy: 1.0
# 362 Train accuracy: 1.0
# 363 Train accuracy: 0.96
# 364 Train accuracy: 0.98
# 365 Train accuracy: 0.98
# 366 Train accuracy: 0.98
# 367 Train accuracy: 0.96
# 368 Train accuracy: 0.98
# 369 Train accuracy: 0.98
# 370 Train accuracy: 1.0
# 371 Train accuracy: 0.96
# 372 Train accuracy: 0.98
# 373 Train accuracy: 1.0
# 374 Train accuracy: 0.96
# 375 Train accuracy: 0.96
# 376 Train accuracy: 0.96
# 377 Train accuracy: 0.98
# 378 Train accuracy: 0.96
# 379 Train accuracy: 1.0
# 380 Train accuracy: 1.0
# 381 Train accuracy: 1.0
# 382 Train accuracy: 0.98
# 383 Train accuracy: 0.98
# 384 Train accuracy: 1.0
# 385 Train accuracy: 1.0
# 386 Train accuracy: 0.98
# 387 Train accuracy: 1.0
# 388 Train accuracy: 1.0
# 389 Train accuracy: 0.98
# 390 Train accuracy: 1.0
# 391 Train accuracy: 1.0
# 392 Train accuracy: 0.98
# 393 Train accuracy: 0.98
# 394 Train accuracy: 0.98
# 395 Train accuracy: 0.96
# 396 Train accuracy: 0.94
# 397 Train accuracy: 0.98
# 398 Train accuracy: 0.98
# 399 Train accuracy: 0.96
# 400 Train accuracy: 0.98
# 401 Train accuracy: 0.98
# 402 Train accuracy: 1.0
# 403 Train accuracy: 1.0
# 404 Train accuracy: 0.98
# 405 Train accuracy: 0.96
# 406 Train accuracy: 1.0
# 407 Train accuracy: 0.96
# 408 Train accuracy: 0.96
# 409 Train accuracy: 0.98
# 410 Train accuracy: 0.98
# 411 Train accuracy: 0.98
# 412 Train accuracy: 1.0
# 413 Train accuracy: 0.96
# 414 Train accuracy: 0.98
# 415 Train accuracy: 0.98
# 416 Train accuracy: 0.98
# 417 Train accuracy: 0.98
# 418 Train accuracy: 1.0
# 419 Train accuracy: 1.0
# 420 Train accuracy: 0.98
# 421 Train accuracy: 1.0
# 422 Train accuracy: 0.96
# 423 Train accuracy: 0.98
# 424 Train accuracy: 0.98
# 425 Train accuracy: 0.98
# 426 Train accuracy: 0.94
# 427 Train accuracy: 0.98
# 428 Train accuracy: 1.0
# 429 Train accuracy: 0.98
# 430 Train accuracy: 1.0
# 431 Train accuracy: 0.98
# 432 Train accuracy: 0.98
# 433 Train accuracy: 0.98
# 434 Train accuracy: 0.98
# 435 Train accuracy: 0.98
# 436 Train accuracy: 0.98
# 437 Train accuracy: 1.0
# 438 Train accuracy: 1.0
# 439 Train accuracy: 0.98
# 440 Train accuracy: 0.96
# 441 Train accuracy: 0.98
# 442 Train accuracy: 0.98
# 443 Train accuracy: 0.94
# 444 Train accuracy: 0.98
# 445 Train accuracy: 0.98
# 446 Train accuracy: 1.0
# 447 Train accuracy: 0.98
# 448 Train accuracy: 1.0
# 449 Train accuracy: 0.98
# 450 Train accuracy: 1.0
# 451 Train accuracy: 0.96
# 452 Train accuracy: 0.96
# 453 Train accuracy: 1.0
# 454 Train accuracy: 0.98
# 455 Train accuracy: 0.98
# 456 Train accuracy: 0.98
# 457 Train accuracy: 0.96
# 458 Train accuracy: 0.98
# 459 Train accuracy: 0.98
# 460 Train accuracy: 1.0
# 461 Train accuracy: 0.98
# 462 Train accuracy: 1.0
# 463 Train accuracy: 0.96
# 464 Train accuracy: 0.96
# 465 Train accuracy: 0.98
# 466 Train accuracy: 0.98
# 467 Train accuracy: 0.98
# 468 Train accuracy: 0.96
# 469 Train accuracy: 1.0
# 470 Train accuracy: 0.98
# 471 Train accuracy: 0.96
# 472 Train accuracy: 0.98
# 473 Train accuracy: 0.96
# 474 Train accuracy: 0.98
# 475 Train accuracy: 0.98
# 476 Train accuracy: 0.96
# 477 Train accuracy: 1.0
# 478 Train accuracy: 0.96
# 479 Train accuracy: 0.98
# 480 Train accuracy: 0.96
# 481 Train accuracy: 0.92
# 482 Train accuracy: 0.96
# 483 Train accuracy: 0.96
# 484 Train accuracy: 0.98
# 485 Train accuracy: 0.98
# 486 Train accuracy: 0.96
# 487 Train accuracy: 0.98
# 488 Train accuracy: 0.96
# 489 Train accuracy: 0.98
# 490 Train accuracy: 0.98
# 491 Train accuracy: 0.98
# 492 Train accuracy: 0.92
# 493 Train accuracy: 0.98
# 494 Train accuracy: 0.98
# 495 Train accuracy: 0.94
# 496 Train accuracy: 0.96
# 497 Train accuracy: 0.98
# 498 Train accuracy: 0.98
# 499 Train accuracy: 1.0
